# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("data.csv") #System2(depth=2)
df2 = pd.read_csv("data1.csv") #System2(depth=1)
df3 = pd.read_csv("data2.csv")#System1
df4 = pd.read_csv("data_sys0.csv")#System 0 random

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10

# %%
mean1 = df1["time"].mean()
mean2 = df2["time"].mean()
mean3 = df3["time"].mean()
mean4 = df4["time"].mean()

# %%
plt.plot(df1["time"], label='System2(depth=2)')
plt.plot(df2["time"]  ,label='System2(depth=1)')
plt.plot(df3["time"]  ,label='System1')
plt.axhline(y=mean1, color='r', linestyle='-')
plt.axhline(y=mean3, color='g', linestyle='-')
plt.axhline(y=mean2, color='orange', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Time')
plt.plot()
plt.legend()

# %%
mean1 = df1["score"].mean()
mean2 = df2["score"].mean()
mean3 = df3["score"].mean()
mean4 = df4["score"].mean()
print(mean1,mean2,mean3,mean4)
# df1 = df1[df1.result != 0]
# df2 = df2[df2.result != 0]
# df3 = df3[df3.result != 0]
# df.head(15)
# Out:
# (1083.3877551020407, 819.63, 942.0204081632653, 894.5555555555555)

# %%
plt.plot(df1.head(100)["score"],label='System2(depth=2)')
plt.plot(df2.head(100)["score"]  ,label='System2(depth=1)')
# plt.plot(df3.head(20)["score"]  ,label='System1')
plt.axhline(y=mean1, color='r', linestyle='-')
plt.axhline(y=mean3, color='orange', linestyle='-')
plt.axhline(y=mean2, color='g', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Score')
plt.plot()
plt.legend()

# %%
plt.plot(df1.head(100)["score"],label='System2(depth=2)')
# plt.plot(df2.head(40)["score"]  ,label='System2(depth=1)')
plt.plot(df3.head(100)["score"]  ,label='System1',color='g')
plt.axhline(y=mean1, color='r', linestyle='-')
plt.axhline(y=mean2, color='orange', linestyle='-')
plt.axhline(y=mean3, color='g', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Score')
plt.plot()
plt.legend()

# %%
# plt.plot(df1.head(20)["score"],label='System1')
plt.plot(df3.head(100)["score"]  ,label='System2(depth=1)')
# plt.plot(df2.head(20)["score"]  ,label='System2(depth=2)')
plt.axhline(y=mean1, color='r', linestyle='-')
plt.axhline(y=mean3, color='orange', linestyle='-')
plt.axhline(y=mean2, color='g', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Score')
plt.plot()
plt.legend()

# %%
# plt.plot(df1.head(20)["score"],label='System1')
# plt.plot(df3.head(20)["score"]  ,label='System2(depth=1)')
plt.plot(df2.head(100)["score"]  ,label='System1')
plt.axhline(y=mean1, color='r', linestyle='-')
plt.axhline(y=mean3, color='orange', linestyle='-')
plt.axhline(y=mean2, color='g', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Score')
plt.plot()
plt.legend()

# %%
plt.plot(df1["time"], label='System2(depth=2)')
plt.plot(df3["time"]  ,label='System2(depth=1)')
plt.plot(df2["time"]  ,label='System1')
plt.plot(df4["time"]  ,label='System0')
# plt.axhline(y=mean1, color='r', linestyle='-')
# plt.axhline(y=mean3, color='orange', linestyle='-')
# plt.axhline(y=mean2, color='g', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Time')
plt.plot()
plt.legend()

# %%
mean1 = df1["score"].mean()
mean2 = df2["score"].mean()
mean3 = df3["score"].mean()
mean4 = df4["score"].mean()

# %%
plt.plot(df1.head(100)["score"],label='System2(depth=2)')
# plt.plot(df2.head(100)["score"]  ,label='System2(depth=1)')
plt.plot(df4.head(100)["score"]  ,label='System0')
plt.plot(df3.head(100)["score"]  ,label='System1')
plt.axhline(y=mean1, color='b', linestyle='-')
plt.axhline(y=mean3, color='orange', linestyle='-')
# plt.axhline(y=mean2, color='g', linestyle='-')
plt.axhline(y=mean4, color='r', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
plt.xlabel('Game Number')
plt.ylabel('Score')
plt.plot()
plt.legend()

# %%
df1 = df1[df1.result != 0]
df2 = df2[df2.result != 0]
df3 = df3[df3.result != 0]
df4 = df4[df4.result != 0]

# %%
print ("System2(Depth=2) = ",df1["result"].count())
print ("System2(Depth=1) = ",df2["result"].count())
print ("System1 = ",df3["result"].count())
print ("System0 = ",df4["result"].count())
# Out:
# ('System2(Depth=2) = ', 88)
# ('System2(Depth=1) = ', 87)
# ('System1 = ', 79)
# ('System0 = ', 86)
